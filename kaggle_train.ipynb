# %% [markdown]
# # RescueNet — PSPNet (ResNet-101) Training
# **Teknofest 2026 | Sentinair Team**
#
# Dataset: [yaroslavchyrko/rescuenet](https://www.kaggle.com/datasets/yaroslavchyrko/rescuenet)
# Model: PSPNet + ResNet-101 (ImageNet pre-trained, 713×713)
# Input: 713×713
#
# **Sınıf seçenekleri (Hücre 4):**
# - **3 sınıf (varsayılan):** Others, Building-Light, Building-Heavy — sadece bina durumu (light/heavy)
# - **USE_CROP = True (plan):** Crop pipeline — orijinal çözünürlükten 896×896 random crop, smart sampling (bina/ağır hasar), 50 epoch, hafif aug. Config: `rescuenet_pspnet101_3class_crop.yaml`
# - **5 sınıf:** + Road-Clear, Road-Blocked
# - **11 sınıf:** Orijinal tüm sınıflar
#
# **Config özeti:** 3-class = `rescuenet_pspnet101_3class.yaml` | 3-class 1024 = `_3class_1024.yaml` | 3-class crop (plan) = `_3class_crop.yaml`
#
# ---
# **Checkpoint:** `checkpoints_pspnet_3class/` (veya _3class_crop, _3class_1024, _5class, pspnet) → Output'tan indir veya Save Version.
# **İlk kez:** Hücreler 1 → 2 → 3 → 4 → 7. **Devam:** 1, 2, 4 (RESUME_PATH doldur), 7.

# %%
# Hücre 1: Repo klonla
import os

REPO_URL = 'https://github.com/nickotyn46/RescueNetModel'  # <-- bunu değiştir
REPO_DIR = '/kaggle/working/RescueNetModel'

if not os.path.exists(REPO_DIR):
    os.system(f'git clone {REPO_URL} {REPO_DIR}')
else:
    print('Repo zaten mevcut, güncelleniyor...')
    os.system(f'cd {REPO_DIR} && git pull')

os.chdir(REPO_DIR)
print(f'Çalışma dizini: {os.getcwd()}')

# %%
# Hücre 2: Bağımlılıkları kur
import os
os.system('pip install -q pyyaml tensorboard tqdm segmentation-models-pytorch')
print('Kurulum tamamlandı.')

# %%
# Hücre 3: GPU ve dataset kontrolü
import torch
print(f'PyTorch  : {torch.__version__}')
print(f'CUDA     : {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU      : {torch.cuda.get_device_name(0)}')
    print(f'VRAM     : {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB')

import os
DATA_ROOT = '/kaggle/input/datasets/yaroslavchyrko/rescuenet/RescueNet'
for split in ['train', 'val', 'test']:
    img_dir = os.path.join(DATA_ROOT, split)
    if os.path.exists(img_dir):
        n = sum(len(f) for _, _, f in os.walk(img_dir))
        print(f'{split:5s}: {n} dosya bulundu')
    else:
        print(f'UYARI: {img_dir} bulunamadı — rescuenet datasetini bu notebook a eklemelisin!')

# %%
# Hücre 4: Config ayarla
# ─────────────────────────────────────────────────────────────────────
# USE_3CLASS = True   → 3 sınıf (sadece bina).
# USE_CROP = True     → Plan: crop pipeline (896 crop, smart sampling, 50 ep, hafif aug) — rescuenet_pspnet101_3class_crop.yaml
# USE_1024 = True     → 1024x1024 (crop kapalıyken, batch 2, VRAM kontrol).
# USE_BUILDING_ONLY   → Sadece bina etiketi olan görüntülerle eğitim (önce liste üretilir).
# DEVAM: RESUME_PATH = '/kaggle/input/.../checkpoints_pspnet_3class_crop/latest.pth'
# ─────────────────────────────────────────────────────────────────────
USE_3CLASS = True
USE_5CLASS = False
USE_CROP = True            # True = crop pipeline (plana göre: 896 crop, 50 ep, building-heavy odak)
USE_BUILDING_ONLY = True   # True = sadece bina içeren görüntüler
USE_1024 = False           # True = 1024x1024 (sadece USE_CROP=False iken)
RESUME_PATH = ''

import yaml, os

DATA_ROOT = '/kaggle/input/datasets/yaroslavchyrko/rescuenet/RescueNet'

if USE_3CLASS:
    if USE_CROP:
        config_path = 'configs/rescuenet_pspnet101_3class_crop.yaml'
        ckpt_dir = '/kaggle/working/checkpoints_pspnet_3class_crop'
        pred_dir = '/kaggle/working/predictions_pspnet_3class_crop'
    elif USE_1024:
        config_path = 'configs/rescuenet_pspnet101_3class_1024.yaml'
        ckpt_dir = '/kaggle/working/checkpoints_pspnet_3class_1024'
        pred_dir = '/kaggle/working/predictions_pspnet_3class_1024'
    else:
        config_path = 'configs/rescuenet_pspnet101_3class.yaml'
        ckpt_dir = '/kaggle/working/checkpoints_pspnet_3class'
        pred_dir = '/kaggle/working/predictions_pspnet_3class'
elif USE_5CLASS:
    config_path, ckpt_dir = 'configs/rescuenet_pspnet101_5class.yaml', '/kaggle/working/checkpoints_pspnet_5class'
    pred_dir = '/kaggle/working/predictions_pspnet_5class'
else:
    config_path, ckpt_dir = 'configs/rescuenet_pspnet101.yaml', '/kaggle/working/checkpoints_pspnet'
    pred_dir = '/kaggle/working/predictions_pspnet'

with open(config_path, 'r') as f:
    cfg = yaml.safe_load(f)

cfg['DATA']['data_root']   = DATA_ROOT
cfg['TRAIN']['save_path']  = ckpt_dir
cfg['TEST']['save_folder'] = pred_dir
cfg['TRAIN']['resume']     = RESUME_PATH

if USE_BUILDING_ONLY and USE_3CLASS:
    building_dir = '/kaggle/working/building_lists'
    os.makedirs(building_dir, exist_ok=True)
    ret = os.system(f'python scripts/build_building_list.py --data_root "{DATA_ROOT}" --out_dir "{building_dir}"')
    if ret == 0:
        cfg['DATA']['building_only_list_dir'] = building_dir
        print(f'Building-only: {building_dir} (train.txt, val.txt)')
    else:
        print('UYARI: build_building_list.py başarısız, tüm veri kullanılacak.')

os.makedirs(ckpt_dir, exist_ok=True)
with open(config_path, 'w') as f:
    yaml.dump(cfg, f, default_flow_style=False)

print(f'Config: {config_path}  (3-class={USE_3CLASS}, crop={USE_CROP}, 1024={USE_1024}, building_only={USE_BUILDING_ONLY})')
print(f'Checkpoint: {ckpt_dir}')
if RESUME_PATH:
    print(f'Devam: {RESUME_PATH}  mevcut={os.path.exists(RESUME_PATH)}')
else:
    print('Sıfırdan başlanacak.')

# %%
# Hücre 5: Sanity check — bir batch yükle (3/5-class ve crop uyumlu)
import sys
import yaml
sys.path.insert(0, '/kaggle/working/RescueNetModel')

from data.dataset import RescueNetDataset, LABEL_MAP_11_TO_5, LABEL_MAP_11_TO_3
from transforms import get_train_transform, get_train_transform_crop

USE_3CLASS = globals().get('USE_3CLASS', False)
USE_5CLASS = globals().get('USE_5CLASS', False)
USE_CROP = globals().get('USE_CROP', False)
config_path = globals().get('config_path', 'configs/rescuenet_pspnet101_3class.yaml')
label_mapping = LABEL_MAP_11_TO_3 if USE_3CLASS else (LABEL_MAP_11_TO_5 if USE_5CLASS else None)

if USE_CROP and USE_3CLASS:
    with open(config_path, 'r') as f:
        _cfg = yaml.safe_load(f)
    crop_size = _cfg.get('TRAIN', {}).get('train_crop_size', 896)
    joint_transform = get_train_transform_crop(crop_size)
    print(f'Crop pipeline: {crop_size}x{crop_size}')
else:
    joint_transform = get_train_transform(713, 713)

ds = RescueNetDataset(
    root_dir='/kaggle/input/datasets/yaroslavchyrko/rescuenet/RescueNet',
    mode='train',
    joint_transform=joint_transform,
    label_mapping=label_mapping,
)
print(f'Train: {len(ds)}  (3-class={USE_3CLASS}, 5-class={USE_5CLASS}, crop={USE_CROP})')
img, mask = ds[0]
print(f'Görüntü: {img.shape}  {img.dtype}')
print(f'Maske  : {mask.shape}  {mask.dtype}')
print(f'Sınıflar: {sorted(mask.unique().tolist())}')

# %%
# Hücre 6: TensorBoard (önce Hücre 4 çalıştır; logdir Hücre 4'teki ckpt_dir/logs)
# %load_ext tensorboard
_tb_logdir = globals().get('ckpt_dir', '/kaggle/working/checkpoints_pspnet_3class') + '/logs'
# %tensorboard --logdir $_tb_logdir

# %%
# Hücre 7: EĞİTİMİ BAŞLAT
# Checkpointler: Hücre 4'teki ckpt_dir (crop: checkpoints_pspnet_3class_crop)
#   best.pth / latest.pth — Oturum bitmeden Output'tan indir veya Save Version!

import os
use3 = globals().get('USE_3CLASS', False)
use5 = globals().get('USE_5CLASS', False)
use_crop = globals().get('USE_CROP', False)
use1024 = globals().get('USE_1024', False)
if use3:
    config_path = 'configs/rescuenet_pspnet101_3class_crop.yaml' if use_crop else ('configs/rescuenet_pspnet101_3class_1024.yaml' if use1024 else 'configs/rescuenet_pspnet101_3class.yaml')
elif use5:
    config_path = 'configs/rescuenet_pspnet101_5class.yaml'
else:
    config_path = 'configs/rescuenet_pspnet101.yaml'
os.system(f'python train.py --config {config_path}')

# %%
# Hücre 8: Checkpoint durumunu kontrol et
import os, torch

use3, use5 = globals().get('USE_3CLASS', False), globals().get('USE_5CLASS', False)
use_crop = globals().get('USE_CROP', False)
use1024 = globals().get('USE_1024', False)
if use3: ckpt_dir = '/kaggle/working/checkpoints_pspnet_3class_crop' if use_crop else ('/kaggle/working/checkpoints_pspnet_3class_1024' if use1024 else '/kaggle/working/checkpoints_pspnet_3class')
elif use5: ckpt_dir = '/kaggle/working/checkpoints_pspnet_5class'
else: ckpt_dir = '/kaggle/working/checkpoints_pspnet'
for fname in ['best.pth', 'latest.pth']:
    path = os.path.join(ckpt_dir, fname)
    if os.path.exists(path):
        ckpt = torch.load(path, map_location='cpu')
        print(f'{fname:12s}  epoch={ckpt["epoch"]:3d}  best_mIoU={ckpt["best_miou"]:.4f}  boyut={os.path.getsize(path)/1e6:.1f}MB')
    else:
        print(f'{fname:12s}  bulunamadı')

# %%
# Hücre 9: Test setinde değerlendir
import os
use3, use5 = globals().get('USE_3CLASS', False), globals().get('USE_5CLASS', False)
use_crop = globals().get('USE_CROP', False)
use1024 = globals().get('USE_1024', False)
if use3: cfg_path = 'configs/rescuenet_pspnet101_3class_crop.yaml' if use_crop else ('configs/rescuenet_pspnet101_3class_1024.yaml' if use1024 else 'configs/rescuenet_pspnet101_3class.yaml')
elif use5: cfg_path = 'configs/rescuenet_pspnet101_5class.yaml'
else: cfg_path = 'configs/rescuenet_pspnet101.yaml'
if use3: ckpt_path = '/kaggle/working/checkpoints_pspnet_3class_crop/best.pth' if use_crop else ('/kaggle/working/checkpoints_pspnet_3class_1024/best.pth' if use1024 else '/kaggle/working/checkpoints_pspnet_3class/best.pth')
elif use5: ckpt_path = '/kaggle/working/checkpoints_pspnet_5class/best.pth'
else: ckpt_path = '/kaggle/working/checkpoints_pspnet/best.pth'
os.system(f'python evaluate.py --config {cfg_path} --model-path {ckpt_path} --save-masks')

# %%
# Hücre 10: ONNX export (Hailo için)
import os
use3, use5 = globals().get('USE_3CLASS', False), globals().get('USE_5CLASS', False)
use_crop = globals().get('USE_CROP', False)
use1024 = globals().get('USE_1024', False)
if use3: cfg_path = 'configs/rescuenet_pspnet101_3class_crop.yaml' if use_crop else ('configs/rescuenet_pspnet101_3class_1024.yaml' if use1024 else 'configs/rescuenet_pspnet101_3class.yaml')
elif use5: cfg_path = 'configs/rescuenet_pspnet101_5class.yaml'
else: cfg_path = 'configs/rescuenet_pspnet101.yaml'
if use3: ckpt_path = '/kaggle/working/checkpoints_pspnet_3class_crop/best.pth' if use_crop else ('/kaggle/working/checkpoints_pspnet_3class_1024/best.pth' if use1024 else '/kaggle/working/checkpoints_pspnet_3class/best.pth')
elif use5: ckpt_path = '/kaggle/working/checkpoints_pspnet_5class/best.pth'
else: ckpt_path = '/kaggle/working/checkpoints_pspnet/best.pth'
out_name = 'rescuenet_pspnet101_3class_crop.onnx' if (use3 and use_crop) else ('rescuenet_pspnet101_3class_1024.onnx' if (use3 and use1024) else ('rescuenet_pspnet101_3class.onnx' if use3 else ('rescuenet_pspnet101_5class.onnx' if use5 else 'rescuenet_pspnet101.onnx')))
os.system(f'python export_onnx.py --config {cfg_path} --model-path {ckpt_path} --output /kaggle/working/{out_name}')

# Output klasöründeki dosyaları listele
print('\n── Output dosyaları ──')
for root, dirs, files in os.walk('/kaggle/working'):
    for f in sorted(files):
        path = os.path.join(root, f)
        rel  = path.replace('/kaggle/working/', '')
        print(f'  {rel:50s}  {os.path.getsize(path)/1e6:.1f} MB')
