# %% [markdown]
# # RescueNet — PSPNet (ResNet-101) Training
# **Teknofest 2026 | Sentinair Team**
#
# Dataset: [yaroslavchyryo/rescuenet](https://www.kaggle.com/datasets/yaroslavchyrko/rescuenet)
# Model: PSPNet + ResNet-101 (ImageNet pre-trained, 713×713 crops as in paper)
# Input: 713×713 | Classes: 11 (veya 5: `configs/rescuenet_pspnet101_5class.yaml` — Building-Light/Heavy, Road, Others)
#
# ---
# **Checkpoint yönetimi:**
# `/kaggle/working/checkpoints_pspnet/` → Kaggle Output sekmesinde görünür, oturum kapanınca da erişilebilir kalır.
# Bir sonraki oturumda devam etmek için Output'u yeni oturuma dataset olarak ekle.
#
# **5 sınıf (önerilen):** Hücre 4'te `USE_5CLASS = True` — bina (hafif/ağır) + yol + others, sınıf ağırlıkları ayarlı.
# **İlk kez:** Hücreleri sırayla 1→7. **Devam:** Hücre 1, 2, 4 (RESUME_PATH) ve 7.

# %%
# Hücre 1: Repo klonla
import os

REPO_URL = 'https://github.com/nickotyn46/RescueNetModel'  # <-- bunu değiştir
REPO_DIR = '/kaggle/working/RescueNetModel'

if not os.path.exists(REPO_DIR):
    os.system(f'git clone {REPO_URL} {REPO_DIR}')
else:
    print('Repo zaten mevcut, güncelleniyor...')
    os.system(f'cd {REPO_DIR} && git pull')

os.chdir(REPO_DIR)
print(f'Çalışma dizini: {os.getcwd()}')

# %%
# Hücre 2: Bağımlılıkları kur
import os
os.system('pip install -q pyyaml tensorboard tqdm segmentation-models-pytorch')
print('Kurulum tamamlandı.')

# %%
# Hücre 3: GPU ve dataset kontrolü
import torch
print(f'PyTorch  : {torch.__version__}')
print(f'CUDA     : {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU      : {torch.cuda.get_device_name(0)}')
    print(f'VRAM     : {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB')

import os
DATA_ROOT = '/kaggle/input/datasets/yaroslavchyrko/rescuenet/RescueNet'
for split in ['train', 'val', 'test']:
    img_dir = os.path.join(DATA_ROOT, split)
    if os.path.exists(img_dir):
        n = sum(len(f) for _, _, f in os.walk(img_dir))
        print(f'{split:5s}: {n} dosya bulundu')
    else:
        print(f'UYARI: {img_dir} bulunamadı — rescuenet datasetini bu notebook a eklemelisin!')

# %%
# Hücre 4: Config ayarla
# ─────────────────────────────────────────────────────────────────────
# USE_5CLASS = True  → 5 sınıf (Others, Building-Light, Building-Heavy, Road-Clear, Road-Blocked)
#                      Sınıf ağırlıkları: Others düşük, bina/yol yüksek (config'te class_weights)
# USE_5CLASS = False → 11 sınıf (orijinal)
# DEVAM EDİYORSAN: RESUME_PATH'i doldur (checkpoints_pspnet veya checkpoints_pspnet_5class)
# ─────────────────────────────────────────────────────────────────────
USE_5CLASS = True   # True = 5 sınıf (ağır hasar + yol odaklı, önerilen)
RESUME_PATH = ''    # Boş = sıfırdan başla; devam: '/kaggle/input/.../checkpoints_pspnet_5class/latest.pth'

import yaml, os

config_path = 'configs/rescuenet_pspnet101_5class.yaml' if USE_5CLASS else 'configs/rescuenet_pspnet101.yaml'
ckpt_dir   = '/kaggle/working/checkpoints_pspnet_5class' if USE_5CLASS else '/kaggle/working/checkpoints_pspnet'
pred_dir   = '/kaggle/working/predictions_pspnet_5class'  if USE_5CLASS else '/kaggle/working/predictions_pspnet'

with open(config_path, 'r') as f:
    cfg = yaml.safe_load(f)

cfg['DATA']['data_root']   = '/kaggle/input/datasets/yaroslavchyrko/rescuenet/RescueNet'
cfg['TRAIN']['save_path']  = ckpt_dir
cfg['TEST']['save_folder'] = pred_dir
cfg['TRAIN']['resume']     = RESUME_PATH

os.makedirs(ckpt_dir, exist_ok=True)

with open(config_path, 'w') as f:
    yaml.dump(cfg, f, default_flow_style=False)

print(f'Config: {config_path}  (5-class={USE_5CLASS})')
print(f'Checkpoint: {ckpt_dir}')
if RESUME_PATH:
    print(f'Devam: {RESUME_PATH}  mevcut={os.path.exists(RESUME_PATH)}')
else:
    print('Sıfırdan başlanacak.')

# %%
# Hücre 5: Sanity check — bir batch yükle (USE_5CLASS ile uyumlu)
import sys
sys.path.insert(0, '/kaggle/working/RescueNetModel')

from data.dataset import RescueNetDataset, LABEL_MAP_11_TO_5
from transforms import get_train_transform

# Hücre 4'te USE_5CLASS tanımlı olmalı; yoksa False
USE_5CLASS = globals().get('USE_5CLASS', False)
label_mapping = LABEL_MAP_11_TO_5 if USE_5CLASS else None

ds = RescueNetDataset(
    root_dir='/kaggle/input/datasets/yaroslavchyrko/rescuenet/RescueNet',
    mode='train',
    joint_transform=get_train_transform(713, 713),
    label_mapping=label_mapping,
)
print(f'Train: {len(ds)}  (5-class={USE_5CLASS})')
img, mask = ds[0]
print(f'Görüntü: {img.shape}  {img.dtype}')
print(f'Maske  : {mask.shape}  {mask.dtype}')
print(f'Sınıflar: {sorted(mask.unique().tolist())}')

# %%
# Hücre 6: TensorBoard (eğitimle paralel). 5-class: checkpoints_pspnet_5class/logs
# %load_ext tensorboard
# %tensorboard --logdir /kaggle/working/checkpoints_pspnet_5class/logs

# %%
# Hücre 7: EĞİTİMİ BAŞLAT
# Checkpointler: Hücre 4'teki ckpt_dir (5-class: checkpoints_pspnet_5class)
#   best.pth / latest.pth — Oturum kapanmadan Output'tan indir veya Save Version!

import os
config_path = 'configs/rescuenet_pspnet101_5class.yaml' if globals().get('USE_5CLASS', False) else 'configs/rescuenet_pspnet101.yaml'
os.system(f'python train.py --config {config_path}')

# %%
# Hücre 8: Checkpoint durumunu kontrol et
import os, torch

ckpt_dir = '/kaggle/working/checkpoints_pspnet_5class' if globals().get('USE_5CLASS', False) else '/kaggle/working/checkpoints_pspnet'
for fname in ['best.pth', 'latest.pth']:
    path = os.path.join(ckpt_dir, fname)
    if os.path.exists(path):
        ckpt = torch.load(path, map_location='cpu')
        print(f'{fname:12s}  epoch={ckpt["epoch"]:3d}  best_mIoU={ckpt["best_miou"]:.4f}  boyut={os.path.getsize(path)/1e6:.1f}MB')
    else:
        print(f'{fname:12s}  bulunamadı')

# %%
# Hücre 9: Test setinde değerlendir
import os
use5 = globals().get('USE_5CLASS', False)
cfg_path = 'configs/rescuenet_pspnet101_5class.yaml' if use5 else 'configs/rescuenet_pspnet101.yaml'
ckpt_path = '/kaggle/working/checkpoints_pspnet_5class/best.pth' if use5 else '/kaggle/working/checkpoints_pspnet/best.pth'
os.system(f'python evaluate.py --config {cfg_path} --model-path {ckpt_path} --save-masks')

# %%
# Hücre 10: ONNX export (Hailo için)
import os
use5 = globals().get('USE_5CLASS', False)
cfg_path = 'configs/rescuenet_pspnet101_5class.yaml' if use5 else 'configs/rescuenet_pspnet101.yaml'
ckpt_path = '/kaggle/working/checkpoints_pspnet_5class/best.pth' if use5 else '/kaggle/working/checkpoints_pspnet/best.pth'
out_name = 'rescuenet_pspnet101_5class.onnx' if use5 else 'rescuenet_pspnet101.onnx'
os.system(f'python export_onnx.py --config {cfg_path} --model-path {ckpt_path} --output /kaggle/working/{out_name}')

# Output klasöründeki dosyaları listele
print('\n── Output dosyaları ──')
for root, dirs, files in os.walk('/kaggle/working'):
    for f in sorted(files):
        path = os.path.join(root, f)
        rel  = path.replace('/kaggle/working/', '')
        print(f'  {rel:50s}  {os.path.getsize(path)/1e6:.1f} MB')
